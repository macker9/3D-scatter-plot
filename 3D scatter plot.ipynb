# %%
#import essential function
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#import excel file
data = pd.read_excel(r'C:\Users\maria\Dropbox (MIT)\Med Sea paper\Tables\PCA data for python.xlsx') #place r before the pathstring
print(data)
# Out:
#              Sample  Depth  Pi concentration         N/P  % Pi uptake  \
# 0   Dagon 2 surface      5                10   21.750271    57.845567
# 1   Dagon 3 surface      5                 5   42.536522    73.752976
# 2   Dagon 4 surface      5                 9   26.311253    84.829038
# 3  Tarhun 8 surface      5                12   68.419742    86.272658
# 4      Dagon 2 deep     50                11   39.437601    62.461419
# 5      Dagon 3 deep     50                 5  112.859134    61.542681
# 6      Dagon 4 deep     50                10   69.541633    53.313017
# 7     Tarhun 8 deep     50                11   66.877382    63.628589
#
#    Turnover  Pi uptake     % phn  Phn production rates        DOP   Score 1  \
# 0  0.192819   1.928186  0.569606              10.983055  0.045687  1.870565
# 1  0.268446   1.342232  0.241689               3.244020  0.044738 -2.044320
# 2  0.191014   1.719122  0.619259              10.645821  0.054266  1.923523
# ...

# %%
from mpl_toolkits.mplot3d import Axes3D
from cycler import cycler
import matplotlib.pyplot as plt
import matplotlib as mpl
import pylab as pl
import numpy as np

#define variables
x =data['Score 1']
y =data['Score 2']
z =data['Score 3']
n =data['Sample']

# %%
#scatter plot
fig = plt.figure(num=1, figsize=(8, 8), dpi=80, facecolor='w', edgecolor='k')
ax = fig.add_subplot(111, projection='3d') #nrows, ncolumns, index
ax.scatter(x, y, z, c='b', marker='o')
ax.grid(True)

ax.set_xlabel('PC1 (45%)')
ax.set_ylabel('PC2 (27%)')
ax.set_zlabel('PC3 (14%)')

ax.set_xlim(-3.5,2.5)
ax.set_ylim(-2, 3.5)
ax.set_zlim(-1, 2)

plt.show()

# %%
#add data labels
for i, label in enumerate(n):
plt.annotate(label, (x[i], y[i], z[i]), *args, **kwargs) 
    
plt.show()
# Out:
#   File "<ipython-input-97-56a0574057ff>", line 3
#     plt.annotate(label, (x[i], y[i], z[i]), *args, **kwargs)
#       ^
# IndentationError: expected an indented block

# %%
#add data labels
from matplotlib.text import Annotation

class Annotation3D(Annotation):
    '''Annotate the point xyz with text s'''

for i, label in enumerate(n):
    def __init__(label, s, (x[i], y[i], z[i]), ):
        Annotation.__init__(label,s, (x[i],y[i])=(0,0), *args, **kwargs)
        self._verts3d = (x[i], y[i], z[i])        

    def draw(self, renderer):
        xs3d, ys3d, zs3d = self._verts3d
        xs, ys, zs = proj_transform(xs3d, ys3d, zs3d, renderer.M)
        self.xy=(xs,ys)
        Annotation.draw(self, renderer)
        
    def annotate3D(ax, s, *args, **kwargs):
    '''add anotation text s to to Axes3d ax'''

    tag = Annotation3D(s, *args, **kwargs)
    ax.add_artist(tag)
        
plt.show()
# Out:
#   File "<ipython-input-90-2142c37a6eb4>", line 8
#     def __init__(label, s, (x[i], y[i], z[i]), *args, **kwargs):
#                            ^
# SyntaxError: invalid syntax
